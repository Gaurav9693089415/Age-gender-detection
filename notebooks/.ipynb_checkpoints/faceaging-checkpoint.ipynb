# %%
# !pip install torch torchvision opencv-python numpy Pillow scikit-learn matplotlib gunicorn Flask-Cors
# Out:
# Requirement already satisfied: Flask in c:\users\patha\anaconda3\lib\site-packages (3.0.3)
# Requirement already satisfied: torch in c:\users\patha\anaconda3\lib\site-packages (2.7.0)
# Requirement already satisfied: torchvision in c:\users\patha\anaconda3\lib\site-packages (0.22.0)
# Requirement already satisfied: opencv-python in c:\users\patha\anaconda3\lib\site-packages (4.11.0.86)
# Requirement already satisfied: numpy in c:\users\patha\anaconda3\lib\site-packages (1.26.4)
# Requirement already satisfied: Pillow in c:\users\patha\anaconda3\lib\site-packages (10.4.0)
# Requirement already satisfied: scikit-learn in c:\users\patha\anaconda3\lib\site-packages (1.6.1)
# Requirement already satisfied: matplotlib in c:\users\patha\anaconda3\lib\site-packages (3.9.2)
# Collecting gunicorn
#   Using cached gunicorn-23.0.0-py3-none-any.whl.metadata (4.4 kB)
# Collecting Flask-Cors
#   Using cached flask_cors-5.0.1-py3-none-any.whl.metadata (961 bytes)
# Requirement already satisfied: Werkzeug>=3.0.0 in c:\users\patha\anaconda3\lib\site-packages (from Flask) (3.0.3)
# Requirement already satisfied: Jinja2>=3.1.2 in c:\users\patha\anaconda3\lib\site-packages (from Flask) (3.1.4)
# Requirement already satisfied: itsdangerous>=2.1.2 in c:\users\patha\anaconda3\lib\site-packages (from Flask) (2.2.0)
# Requirement already satisfied: click>=8.1.3 in c:\users\patha\anaconda3\lib\site-packages (from Flask) (8.1.7)
# Requirement already satisfied: blinker>=1.6.2 in c:\users\patha\anaconda3\lib\site-packages (from Flask) (1.6.2)
# Requirement already satisfied: filelock in c:\users\patha\anaconda3\lib\site-packages (from torch) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\users\patha\anaconda3\lib\site-packages (from torch) (4.11.0)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\patha\anaconda3\lib\site-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx in c:\users\patha\anaconda3\lib\site-packages (from torch) (3.3)
# Requirement already satisfied: fsspec in c:\users\patha\anaconda3\lib\site-packages (from torch) (2024.6.1)
# Requirement already satisfied: setuptools in c:\users\patha\anaconda3\lib\site-packages (from torch) (75.1.0)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\patha\anaconda3\lib\site-packages (from scikit-learn) (1.15.1)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\patha\anaconda3\lib\site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\patha\anaconda3\lib\site-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\patha\anaconda3\lib\site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\patha\anaconda3\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\patha\anaconda3\lib\site-packages (from matplotlib) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\patha\anaconda3\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\patha\anaconda3\lib\site-packages (from matplotlib) (24.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\patha\anaconda3\lib\site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\patha\anaconda3\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: colorama in c:\users\patha\anaconda3\lib\site-packages (from click>=8.1.3->Flask) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\patha\anaconda3\lib\site-packages (from Jinja2>=3.1.2->Flask) (2.1.3)
# Requirement already satisfied: six>=1.5 in c:\users\patha\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\patha\anaconda3\lib\site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Using cached gunicorn-23.0.0-py3-none-any.whl (85 kB)
# Using cached flask_cors-5.0.1-py3-none-any.whl (11 kB)
# Installing collected packages: gunicorn, Flask-Cors
# Successfully installed Flask-Cors-5.0.1 gunicorn-23.0.0

# %%
import os
import torch
from torch.utils.data import Dataset
from PIL import Image
import torchvision.transforms as transforms
import cv2
import numpy as np

class UTKFaceDataset(Dataset):
    def __init__(self, image_dir, transform=None):
        """
        Args:
            image_dir (string): Path to the directory containing images.
            transform (callable, optional): Optional transform to be applied on a sample.
        """
        self.image_dir = image_dir
        self.transform = transform
        self.images = os.listdir(image_dir)

    def __len__(self):
        return len(self.images)

    def __getitem__(self, idx):
        image_name = self.images[idx]
        image_path = os.path.join(self.image_dir, image_name)
        image = Image.open(image_path)

        # Parse the label from the filename: age_gender_race_date_time
        label = image_name.split('_')
        age = int(label[0]) // 5  # Convert age to a 5-year range (age/5)
        gender = int(label[1])  # 0 for male, 1 for female

        # Convert image to numpy array for processing
        image = np.array(image)

        # Apply face detection and cropping
        image = self.detect_and_crop_face(image)

        # If face is not detected, return None (or handle it as needed)
        if image is None:
            return None

        # Resize and apply transformations
        if self.transform:
            image = self.transform(image)

        return image, (age, gender)

    def detect_and_crop_face(self, image):
        """
        Detect face and crop it using OpenCV.
        We are using the Haar Cascade Classifier for face detection.
        """
        gray = cv2.cvtColor(image, cv2.COLOR_RGB2GRAY)
        face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')
        faces = face_cascade.detectMultiScale(gray, 1.1, 4)
        
        if len(faces) == 0:
            return None  # No face detected
        
        # Crop the first face detected (you can modify this to handle multiple faces)
        x, y, w, h = faces[0]
        image = image[y:y+h, x:x+w]
        
        return image
